# %% [markdown]
# <a href="https://colab.research.google.com/github/MR-Sambit/Crop-_Disease_Detection__v3.0/blob/new/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-15f6b2d0-389b-4533-b6e1-706be223dc6b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15f6b2d0-389b-4533-b6e1-706be223dc6b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir ~/.kaggle
# !cp kaggle (1).json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle (1).json
# !kaggle datasets download -d emmarex/plantdisease
# !unzip plantdisease.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: plantvillage/PlantVillage/Tomato__Tomato_YellowLeaf__Curl_Virus/08c033bd-fbc3-445a-88d1-1863070e52ce___YLCV_GCREC 2872.JPG
#   inflating: plantvillage/PlantVillage/Tomato__Tomato_YellowLeaf__Curl_Virus/08dd176c-e9d9-4746-92c3-fa8dc9074347___UF.GRC_YLCV_Lab 03057.JPG
#   inflating: plantvillage/PlantVillage/Tomato__Tomato_YellowLeaf__Curl_Virus/08f78a80-46f5-45a6-937c-4d05d61c08c2___UF.GRC_YLCV_Lab 01895.JPG
#   inflating: plantvillage/PlantVillage/Tomato__Tomato_YellowLeaf__Curl_Virus/0903aa95-6e8a-4abd-a003-126fcd9a5493___YLCV_GCREC 2806.JPG
#   inflating: plantvillage/PlantVillage/Tomato__Tomato_YellowLeaf__Curl_Virus/0911d416-d73d-4c2a-8e45-207a7ceb7c9a___YLCV_GCREC 2773.JPG
#   inflating: plantvillage/PlantVillage/Tomato__Tomato_YellowLeaf__Curl_Virus/09188838-cc89-4925-94c5-d9563c4cb4bf___UF.GRC_YLCV_Lab 02974.JPG
# ...

# %%
import os

base_dir = '/content/PlantVillage'  # Change if needed
print("Contents of /content/PlantVillage:", os.listdir(base_dir))
# Out:
# Contents of /content/PlantVillage: ['Tomato_healthy', 'Pepper__bell___Bacterial_spot', 'Tomato_Late_blight', 'Tomato__Tomato_mosaic_virus', 'Tomato__Target_Spot', 'Pepper__bell___healthy', 'Tomato_Septoria_leaf_spot', 'Tomato_Leaf_Mold', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato_Bacterial_spot', 'Potato___Early_blight', 'Tomato_Early_blight', 'Potato___healthy', 'Potato___Late_blight', 'Tomato__Tomato_YellowLeaf__Curl_Virus']

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# Define the image size and batch size
img_width, img_height = 128, 128
batch_size = 32

# Define dataset path (Only one folder, no separate train/val)
dataset_dir = '/content/PlantVillage'  # The actual dataset folder

# Verify dataset location
print("Contents of /content/:", os.listdir('/content/'))

# Create ImageDataGenerator with validation split
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2  # 20% for validation
)

# Training Data Generator
train_generator = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Training subset
)

# Validation Data Generator
validation_generator = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Validation subset
)

# Get the number of classes
num_classes = train_generator.num_classes

# Define the CNN model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(img_width, img_height, 3)),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(256, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),

    GlobalAveragePooling2D(),
    Dropout(0.5),

    Dense(512, activation='relu'),
    Dropout(0.5),

    Dense(num_classes, activation='softmax')  # Output layer
])

# Compile the model
model.compile(optimizer=RMSprop(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Contents of /content/: ['.config', 'kaggle (1).json', 'PlantVillage', 'plantvillage', 'plantdisease.zip', 'sample_data']
# Found 16516 images belonging to 15 classes.
# Found 4122 images belonging to 15 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 126, 126, 32)        │             896 │
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.optimizers import RMSprop
import os

# Define the image size and batch size
img_width, img_height = 128, 128
batch_size = 32

# Define dataset path
dataset_path = '/content/PlantVillage'  # Adjust as needed

# Verify dataset location
print("Contents of dataset folder:", os.listdir(dataset_path))

# Data Augmentation & Normalization
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    validation_split=0.2  # 80-20 split
)

# No augmentation for validation; only rescaling
valid_datagen = ImageDataGenerator(rescale=1.0 / 255, validation_split=0.2)

# Load Training Data
train_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

# Load Validation Data
validation_generator = valid_datagen.flow_from_directory(
    dataset_path,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# Get number of classes
num_classes = train_generator.num_classes

# Define CNN Model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(img_width, img_height, 3)),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(256, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),

    GlobalAveragePooling2D(),
    Dropout(0.5),

    Dense(512, activation='relu'),
    Dropout(0.5),

    Dense(num_classes, activation='softmax')  # Output layer
])

# Compile the model
model.compile(optimizer=RMSprop(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()

# Optional: Check data distribution
print(f"Training samples: {train_generator.samples}")
print(f"Validation samples: {validation_generator.samples}")

# Train the model
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=20,  # Adjust as needed
    verbose=1
)

# Save the model
model.save("plant_disease_model.h5")
print("Model saved successfully!")
# Out:
# Contents of dataset folder: ['Tomato_healthy', 'Pepper__bell___Bacterial_spot', 'Tomato_Late_blight', 'Tomato__Tomato_mosaic_virus', 'Tomato__Target_Spot', 'Pepper__bell___healthy', 'Tomato_Septoria_leaf_spot', 'Tomato_Leaf_Mold', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato_Bacterial_spot', 'Potato___Early_blight', 'Tomato_Early_blight', 'Potato___healthy', 'Potato___Late_blight', 'Tomato__Tomato_YellowLeaf__Curl_Virus']
# Found 16516 images belonging to 15 classes.
# Found 4122 images belonging to 15 classes.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 126, 126, 32)        │             896 │
# ...

# %%
import keras.saving
keras.saving.save_model(model, "best_model.keras")

# %%
print(history)
print(history.history.keys())
print(history.history)
# Out:
# ...
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# ...

# %%
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d

# Extract loss and accuracy from training history
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Apply Gaussian smoothing
smooth_acc = gaussian_filter1d(acc, sigma=1)
smooth_val_acc = gaussian_filter1d(val_acc, sigma=1)
smooth_loss = gaussian_filter1d(loss, sigma=1)
smooth_val_loss = gaussian_filter1d(val_loss, sigma=1)

epochs = range(len(acc))  # Number of epochs

# Plot Training & Validation Accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, smooth_acc, 'b', label='Training Accuracy (smoothed)')
plt.plot(epochs, smooth_val_acc, 'r', label='Validation Accuracy (smoothed)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy')
plt.legend()

# Plot Training & Validation Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, smooth_loss, 'b', label='Training Loss (smoothed)')
plt.plot(epochs, smooth_val_loss, 'r', label='Validation Loss (smoothed)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# Assuming you want to evaluate on the validation set:
test_generator = validation_generator  # Use validation_generator as test_generator

# Get the true labels and predictions
Y_true = test_generator.classes  # True labels
Y_pred_prob = model.predict(test_generator)  # Predictions (probabilities)
Y_pred = np.argmax(Y_pred_prob, axis=1)  # Convert probabilities to class indices

# Get class labels from the generator
class_labels = list(test_generator.class_indices.keys())

# Compute confusion matrix
cm = confusion_matrix(Y_true, Y_pred)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# Print classification report
print("Classification Report:\n", classification_report(Y_true, Y_pred, target_names=class_labels))
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step
# Classification Report:
#                                               precision    recall  f1-score   support
#
#               Pepper__bell___Bacterial_spot       0.04      0.06      0.05       199
#                      Pepper__bell___healthy       0.06      0.09      0.07       295
#                       Potato___Early_blight       0.04      0.07      0.05       200
#                        Potato___Late_blight       0.05      0.05      0.05       200
#                            Potato___healthy       0.00      0.00      0.00        30
#                       Tomato_Bacterial_spot       0.12      0.12      0.12       425
#                         Tomato_Early_blight       0.04      0.03      0.03       200
#                          Tomato_Late_blight       0.11      0.08      0.09       381
#                            Tomato_Leaf_Mold       0.06      0.03      0.04       190
# ...

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# Load and preprocess the image
img_path = '/content/bt1.jpg'  # Replace with your test image
img = image.load_img(img_path, target_size=(128, 128))
img_array = image.img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Predict
predictions = model.predict(img_array)
predicted_class_index = np.argmax(predictions, axis=1)[0]
confidence_score = np.max(predictions) * 100  # Get confidence percentage

# Map class index to label
class_labels = list(train_generator.class_indices.keys())
predicted_label = class_labels[predicted_class_index]

# Ensure proper handling of class names
if "___" in predicted_label:
    plant, disease = predicted_label.split("___")
else:
    plant = predicted_label
    disease = "Unknown"

# Print detailed output
print("=" * 50)
print(f"🌱 Identified Plant: {plant}")
print(f"🦠 Detected Disease: {disease}")
print(f"🎯 Confidence Score: {confidence_score:.2f}%")
print("=" * 50)

# Optional: Show all class probabilities
print("\n🔍 Class Probabilities:")
for i, label in enumerate(class_labels):
    print(f"  {label}: {predictions[0][i] * 100:.2f}%")

# Dictionary containing remedies for each disease
disease_remedies = {
    "Bacterial_spot": "🛑 Use copper-based fungicides and avoid overhead watering. Remove infected leaves.",
    "Early_blight": "🌿 Apply fungicides like chlorothalonil or copper sprays. Rotate crops for better health.",
    "Late_blight": "🔥 Use fungicides like mancozeb or chlorothalonil. Destroy infected plants to prevent spread.",
    "Leaf_Mold": "💨 Ensure good air circulation, avoid excessive moisture, and use copper-based sprays.",
    "Septoria_leaf_spot": "🔄 Apply fungicides, remove affected leaves, and practice crop rotation.",
    "Spider_mites_Two_spotted_spider_mite": "🐞 Use neem oil or insecticidal soap. Introduce natural predators like ladybugs.",
    "Target_Spot": "🛠 Use fungicides and improve field drainage. Avoid planting in infected soil.",
    "Tomato_YellowLeaf_Curl_Virus": "🦟 Control whiteflies with insecticidal sprays. Use resistant tomato varieties.",
    "Tomato_mosaic_virus": "⚠️ Remove infected plants. Disinfect tools to prevent spread.",
    "Healthy": "✅ No disease detected! Keep up with proper plant care. 👍"
}

# Print the remedy for the detected disease
remedy = disease_remedies.get(disease, "⚠️ No specific remedy found for this disease.")
print("\n💡 Recommended Remedy:")
print(remedy)
print("=" * 50)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ...
# 🌱 Identified Plant: Pepper__bell
# 🦠 Detected Disease: Bacterial_spot
# 🎯 Confidence Score: 98.76%
# ...
#
# 🔍 Class Probabilities:
#   Pepper__bell___Bacterial_spot: 98.76%
#   Pepper__bell___healthy: 0.00%
#   Potato___Early_blight: 0.11%
#   Potato___Late_blight: 0.00%
#   Potato___healthy: 0.00%
#   Tomato_Bacterial_spot: 0.01%
#   Tomato_Early_blight: 0.03%
#   Tomato_Late_blight: 0.01%
#   Tomato_Leaf_Mold: 0.00%
#   Tomato_Septoria_leaf_spot: 1.07%
#   Tomato_Spider_mites_Two_spotted_spider_mite: 0.00%
#   Tomato__Target_Spot: 0.00%
#   Tomato__Tomato_YellowLeaf__Curl_Virus: 0.01%
#   Tomato__Tomato_mosaic_virus: 0.00%
#   Tomato_healthy: 0.00%
#
# 💡 Recommended Remedy:
# 🛑 Use copper-based fungicides and avoid overhead watering. Remove infected leaves.
# ...

# %%
model.save("/content/plant_disease_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# This saves the entire model, including weights, architecture, and training configuration.

# %%
# Modified Code: Using '.h5' extension
model.save("/content/plant_disease_model.h5")

# OR

# Modified Code: Using '.keras' extension
# model.save("/content/plant_disease_model.keras")  # Native Keras format
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf

# Load the saved model
model = tf.keras.models.load_model("/content/plant_disease_model.h5")

# Convert the model to TFLite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TFLite model
with open("/content/plant_disease_model.tflite", "wb") as f:
    f.write(tflite_model)

print("TFLite model saved successfully!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved artifact at '/tmp/tmpnmveagpz'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 15), dtype=tf.float32, name=None)
# Captures:
#   138961476544144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138961476550096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138961476545296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138961476548176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138961476548944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138961476543952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138961476542032: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Copy model to Google Drive
# !cp plant_disease_model.tflite /content/drive/MyDrive/
print("Model saved to Google Drive.")
# Out:
# Mounted at /content/drive
# Model saved to Google Drive.

# %%
from google.colab import files

# Save the model with a proper name
tflite_model_path = "plant_disease_model.tflite"
with open(tflite_model_path, "wb") as f:
    f.write(tflite_model)

# Download to your local machine
files.download(tflite_model_path)
